# %% [markdown]
# <a href="https://colab.research.google.com/github/connectasp/Pandas_GuviTask4/blob/main/Pandas_GuviTask4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
college1 = pd.read_csv("college_1.csv")
college1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
college2 = pd.read_csv("college_2.csv")
college2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
college = college1.append(college2)
college
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
ckscore_greater15000 = college[college["CodeKata Score"] > 15000]
ckscore_greater15000
ckscore_greater15000.to_csv("Exceeded_Expectations.csv")

# %%
ckscore_10kto15k = college[(college["CodeKata Score"] <= 15000) & (college["CodeKata Score"] >= 10000) ]
ckscore_10kto15k.to_csv("Reached_expectations.csv")
ckscore_10kto15k
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
ckscore_7kto10k = college[(college["CodeKata Score"] < 10000) & (college["CodeKata Score"] >= 7000) ]
ckscore_7kto10k.to_csv("Needs_Improvement.csv")
ckscore_7kto10k
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
ckscore_lessthan7000 = college[college["CodeKata Score"] < 7000]
ckscore_lessthan7000.to_csv("Unsatisfactory.csv")
ckscore_lessthan7000
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg =college[["Previous Geekions","CodeKata Score"]].mean()
avg
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
No_of_Student = college["Name"].count()
print("No of Students Participated are", No_of_Student)
# Out:
# No of Students Participated are 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
avg_completion =college[["python","mysql","python_en","computational_thinking"]].mean()
avg_completion
# Out:
# python                    54.352941
# mysql                     23.500000
# python_en                 29.657143
# computational_thinking     2.200000
# dtype: float64

# %%
PY = college["python"].mean()
SQL = college["mysql"].mean()
PY_EN = college["python_en"].mean()
CT = college["computational_thinking"].mean()
print("The average Completion of SQL is : ",SQL)
print("The average Completion of Python is : ", PY)
print("The average Completion of Python English is : ",PY_EN)
print("The average Completion of computational_thinking is : ",CT)
# Out:
# The average Completion of SQL is :  23.5
# The average Completion of Python is :  54.35294117647059
# The average Completion of Python English is :  29.65714285714286
# The average Completion of computational_thinking is :  2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star = college[['Name','Previous Geekions']]
rising_star.nlargest(3, 'Previous Geekions')
# Out:
#           Name  Previous Geekions
# 0    A.Dharani              24500
# 1  V.JEEVITHA               21740
# 2  HEMAVATHI.R              19680

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_star = college[['Name','CodeKata Score']]
shining_star.nlargest(3, 'CodeKata Score')
# Out:
#           Name  CodeKata Score
# 0    A.Dharani           24500
# 1  V.JEEVITHA            21740
# 2  HEMAVATHI.R           19680

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dept_codekata = college[['Department','CodeKata Score']]
dept_codekata.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%',figsize=(20,10))

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
CS = college[college["Department"]=="Computer Science and Engineering"]
CS.sort_values(["CodeKata Score"],ascending = False,inplace=True)
X = CS["Name"].head(5)
Y = CS["CodeKata Score"].head(5)
plt.figure(figsize=(8,5), dpi=70)
plt.bar(X,Y)
plt.title("Computer Science and Engineering")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
ECE = college[college["Department"]=="Electronics and Communication Engineering"]
ECE.sort_values(["CodeKata Score"],ascending = False,inplace=True)
X = ECE["Name"].head(5)
Y = ECE["CodeKata Score"].head(5)
plt.figure(figsize=(8,5), dpi=70)
plt.bar(X,Y)
plt.title("Electronics and Communication Engineering")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
EEE = college[college["Department"]=="Electronics and Electrical Engineering"]
EEE.sort_values(["CodeKata Score"],ascending = False,inplace=True)
X = EEE["Name"].head(5)
Y = EEE["CodeKata Score"].head(5)
plt.figure(figsize=(8,5), dpi=70)
plt.bar(X,Y)
plt.title("Electronics and Electrical Engineering")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
